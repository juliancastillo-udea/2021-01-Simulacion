# %% [markdown]
# # Ejercicios Clase 01
# ## Python y yo, los nuevos mejores amigos.
#
# Ejercicios relacionados con el entorno Python.

# %% [markdown]
# ## Ejercicio 1
# <p>
# Batman compra sus artefactos y dispositivos para combatir el crimen, mediante una empresa subsidiaria de Wayne Enterprises en la cual deben hacer pedidos muy grandes y variados para evitar que identifiquen que Bruce Wayne es Batman. Debido a esto Bruce Wayne necesita que usted, un magnifico estudiante de Ingeniería Industrial de la UdeA, realice una función en Python con Google Colab mediante la cual calcule la cantidad de artefactos y dispositivos que necesita pedir el Señor Lucius Fox mediante dicha empresa subsidiaria utilizando la siguiente tabla.
# </p>
#
# Ítem | Mes | Tipo | Aleatorio Nivel Inferior Pedido | Aleatorio Nivel Superior Pedido
# --- | --- | --- | --- | ---
# Batarang | Par | Artefacto | 1500 | 3500
# Batarang | Impar | Artefacto | 2500 | 4500
# Grappling Gun | Par | Dispositivo | 15 | 30
# Grappling Gun | Impar | Dispositivo | 10 | 20
# Ultrasonic Bat Beacon | Par | Dispositivo | 5 | 7
# Ultrasonic Bat Beacon | Impar | Dispositivo | 9 | 11
# Gauntlets | Par | Artefacto | 250 | 300
# Gauntlets | Impar | Artefacto | 400 | 450

# %%
#Solucion
import random as rnd

# %%
strItem = input('Ingresar el item, en minusculas: ')
strMes = input('Ingresar el mes en formato entero: ')
intMes = int(strMes)
# Podemos Clasificar por Item o por Mes --> Mes
if (intMes % 2 == 0):
    if (strItem == 'batarang'):
        fltResultado = rnd.randint(1500,3500)
    elif (strItem == 'grappling gun'):
        fltResultado = rnd.randint(15,30)
    elif (strItem == 'ultrasonic bat beacon'):
        fltResultado = rnd.randint(5,7)
    elif (strItem == 'gauntlets'):
        fltResultado = rnd.randint(250,300)
    #Estaria en el condicional anidado
#estoy en el condicional mes par, si hago else estoy mes impar
else:
    if (strItem == 'batarang'):
        fltResultado = rnd.randint(2500,3500)
    elif (strItem == 'grappling gun'):
        fltResultado = rnd.randint(10,20)
    elif (strItem == 'ultrasonic bat beacon'):
        fltResultado = rnd.randint(9,11)
    elif (strItem == 'gauntlets'):
        fltResultado = rnd.randint(400,450)
#Por fuera de los condicionales
print("Para la siguiente situación: Batman, perdon Don Bruce, Necesita {0} de {1} para el mes {2}".format(fltResultado, strItem, intMes))
# Out:
# Ingresar el item, en minusculas: batarang
# Ingresar el mes en formato entero: 12
# Para la siguiente situación: Batman, perdon Don Bruce, Necesita 12 de batarang para el mes 2591

# %%
#Ahora en modo función
def BatmanNoesBruceWayne(Item, Mes):
    strItem = str(Item)
    intMes = int(Mes)
    # Podemos Clasificar por Item o por Mes --> Mes
    if (intMes % 2 == 0):
        if (strItem == 'batarang'):
            fltResultado = rnd.randint(1500,3500)
        elif (strItem == 'grappling gun'):
            fltResultado = rnd.randint(15,30)
        elif (strItem == 'ultrasonic bat beacon'):
            fltResultado = rnd.randint(5,7)
        elif (strItem == 'gauntlets'):
            fltResultado = rnd.randint(250,300)
        #Estaria en el condicional anidado
    #estoy en el condicional mes par, si hago else estoy mes impar
    else:
        if (strItem == 'batarang'):
            fltResultado = rnd.randint(2500,3500)
        elif (strItem == 'grappling gun'):
            fltResultado = rnd.randint(10,20)
        elif (strItem == 'ultrasonic bat beacon'):
            fltResultado = rnd.randint(9,11)
        elif (strItem == 'gauntlets'):
            fltResultado = rnd.randint(400,450)
    #Por fuera de los condicionales
    strResultado = "Para la siguiente situación: Batman, perdon Don Bruce, Necesita " + str(fltResultado) + " de " + strItem + " para el mes " + str(intMes)
    return strResultado
print(BatmanNoesBruceWayne('batarang', 12))
# Out:
# Para la siguiente situación: Batman, perdon Don Bruce, Necesita 3048 de batarang para el mes 12

# %% [markdown]
# ## Ejercicio 2
# <p>
# Realizar una función que solucione ecuaciones cuadráticas.
# </p>
#
# ![Imagen](https://upload.wikimedia.org/wikipedia/commons/thumb/c/c8/Ecuaci%C3%B3n_cuadr%C3%A1tica.svg/800px-Ecuaci%C3%B3n_cuadr%C3%A1tica.svg.png)

# %%
#Solucion

# %% [markdown]
# ## Ejercicio 3
# <p>
# Realizar una función que utilizando el teorema del Seno solucione para un Angulo y para un lado de su elección.
# </p>
#
# ![Imagen](https://matematicasies.com/local/cache-vignettes/L546xH257/teorema_senos_2-932d7.png?1587880614)

# %%
#Solucion

# %% [markdown]
# ## Ejercicio 4
# <p>
# Realizar una función que utilizando el teorema del Coseno solucione para un Angulo y para un lado
# </p>
#
# ![Imagen](https://www.matesfacil.com/BAC/trigonometria/teorema/coseno/TCOS1.png)

# %%
#Solucion

# %% [markdown]
# ## Ejercicio 4
# <p>
# Construya una función en Python que calcule la distancia entre dos puntos P y Q, con los siguientes parámetros de entrada: X1, X2, Y1, Y2. Recuerde que los puntos se representan mediante coordenadas X e Y.
# </p>
#
# ![Imagen](https://lh3.googleusercontent.com/proxy/q8q8Eu4xN-mH8gGifmAyYapeOcPGndY55ges8UvX4HkiLBUQQMS3BZpbPbjTYL87MZmkfkx1SDDGeo6J5cD4aQK_pzbxCoeC8w7kNY3i)
